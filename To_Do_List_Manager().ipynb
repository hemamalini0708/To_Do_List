# %% [markdown]
# <a href="https://colab.research.google.com/github/hemamalini0708/To_Do_List/blob/main/To_Do_List_Manager().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def todo_list_manager():
    tasks = []

    while True:
        print("\nTO DO LIST MANAGER")
        print("1. ADD NEW TASK")
        print("2. REMOVE TASK")
        print("3. VIEW TASKS")
        print("4. EXIT")

        choice = input("ENTER YOUR CHOICE: ")

        if choice == "1":
            task = input("ENTER YOUR TASK: ")
            tasks.append(task)
            print(f"Task '{task}' added.")

        elif choice == "2":
            task = input("ENTER TASK TO REMOVE: ")
            if task in tasks:
                tasks.remove(task)
                print(f"Task '{task}' removed.")
            else:
                print(f"Task '{task}' not found.")

        elif choice == "3":
            print("\nCurrent Tasks:")
            if tasks:
                for i, task in enumerate(tasks, 1):
                    print(f"{i}. {task}")
            else:
                print("No tasks to show.")

        elif choice == "4":
            print("Exiting To-Do List Manager.")
            break

        else:
            print("Invalid choice. Please try again.")

todo_list_manager()
# Out:
# TO DO LIST MANAGER
# 1. ADD NEW TASK
# 2. REMOVE TASK
# 3. VIEW TASKS
# 4. EXIT
# ENTER YOUR CHOICE: 1
# ENTER YOUR TASK: Exercise
# Task 'Exercise' added.
#
# TO DO LIST MANAGER
# 1. ADD NEW TASK
# 2. REMOVE TASK
# 3. VIEW TASKS
# 4. EXIT
# ENTER YOUR CHOICE: 1
# ENTER YOUR TASK: Drink Water
# Task 'Drink Water' added.
#
# TO DO LIST MANAGER
# 1. ADD NEW TASK
# 2. REMOVE TASK
# 3. VIEW TASKS
# 4. EXIT
# ENTER YOUR CHOICE: 1
# ENTER YOUR TASK: Bath
# Task 'Bath' added.
#
# TO DO LIST MANAGER
# 1. ADD NEW TASK
# 2. REMOVE TASK
# 3. VIEW TASKS
# 4. EXIT
# ENTER YOUR CHOICE: 1
# ENTER YOUR TASK: Pray
# Task 'Pray' added.
#
# TO DO LIST MANAGER
# 1. ADD NEW TASK
# 2. REMOVE TASK
# 3. VIEW TASKS
# 4. EXIT
# ENTER YOUR CHOICE: 1
# ENTER YOUR TASK: BreakFast
# Task 'BreakFast' added.
#
# TO DO LIST MANAGER
# 1. ADD NEW TASK
# 2. REMOVE TASK
# 3. VIEW TASKS
# 4. EXIT
# ENTER YOUR CHOICE: 1
# ENTER YOUR TASK: Play chess
# Task 'Play chess' added.
#
# TO DO LIST MANAGER
# 1. ADD NEW TASK
# ...
